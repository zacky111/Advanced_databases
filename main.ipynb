# %% [markdown]
# **Import datasetu**
# https://www.kaggle.com/datasets/tunguz/covid19-finance-sector-related-policy-responses

# %%
import pandas as pd

file_path = 'sources\\covid-fci-data.csv'

df = pd.read_csv(file_path, encoding='mac_roman')
df.head()
# Out:
#    ID                                       Country Name Country ISO3  \
# 0   1  China                                                    CHN
# 1   2  Canada                                                   CAN
# 2   3  China                                                    CHN
# 3   4  Thailand                                                 THA
# 4   5  Russian Federation                                       RUS
#
#           Income Level Authority     Date Level 1 policy measures  \
# 0  Upper middle income     SUP     2/1/20  Banking sector
# 1  High income             CB     3/13/20  Liquidity/funding
# 2  Upper middle income     CB      2/5/20  Banking sector
# 3  Upper middle income     CB      2/5/20  Liquidity/funding
# 4  Upper middle income     CB      2/7/20  Liquidity/funding
#
#                              Level 2 policy measures  \
# 0  Operational continuity                        ...
# 1  Liquidity (incl FX)/ELA                       ...
# 2  Integrity                                     ...
# 3  Policy rate                                   ...
# 4  Policy rate                                   ...
#
#                              Level 3 policy measures  \
# 0  Blank                                         ...
# 1  Blank                                         ...
# 2  Other integrity                               ...
# 3  Blank                                         ...
# 4  Blank                                         ...
#
#                               Details of the measure  \
# 0  Require banks and insurance companies to ensur...
# 1  BoC also created a Bankers Acceptance Purchase...
# 2  The PBC has issued Notices on AML/CFT requirem...
# 3  BOT cut its benchmark interest rate by 25 basi...
# 4  Policy rates were reduced by 25 basis points t...
#
#                                            Reference Termination Date  \
# 0  http://www.gov.cn/zhengce/zhengceku/2020-02/03...              NaN
# 1  https://www.bankofcanada.ca/markets/market-ope...         10/31/20
# 2                                                ...              NaN
# 3  https://www.bot.or.th/English/PressandSpeeches...              NaN
# 4  https://www.cnbc.com/2020/02/07/reuters-americ...              NaN
#
#   Modification of Parent Measure  Parent Measure
# 0                      No                    NaN
# 1                      No                    NaN
# 2                      No                    NaN
# 3                      No                    NaN
# 4                      No                    NaN

# %% [markdown]
# **Sprawdzenie jak dużo NaN**

# %%
missing_data = pd.DataFrame({
    'missing_count': df.isna().sum(),
    'missing_percent': (df.isna().sum() / len(df)) * 100,
    'unique_values': df.nunique()
})

missing_data = missing_data.sort_values('missing_count', ascending=False)
missing_data


print(df.len())
# Out:
#                                 missing_count  missing_percent  unique_values
# Parent Measure                           3175        85.280688            242
# Termination Date                         2983        80.123556             98
# Date                                        1         0.026860            262
# Country ISO3                                0         0.000000            157
# Country Name                                0         0.000000            157
# ID                                          0         0.000000           2872
# Authority                                   0         0.000000              7
# Income Level                                0         0.000000              6
# Level 1 policy measures                     0         0.000000              5
# Level 2 policy measures                     0         0.000000             19
# Details of the measure                      0         0.000000           2828
# Level 3 policy measures                     0         0.000000             40
# Reference                                   0         0.000000           1620
# Modification of Parent Measure              0         0.000000              5
